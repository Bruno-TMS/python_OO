# %%
def dobro(x):
    return x*2

# %%
dobro2 = lambda x: x*2

# %%
from dis import dis
dis(dobro.__code__.co_code)
# Out:
#           0 RESUME                   0
#           2 LOAD_FAST                0
#           4 LOAD_CONST               1
#           6 BINARY_OP                5 (*)
#          10 RETURN_VALUE

# %%
from dis import dis
dis(dobro2.__code__.co_code)
# Out:
#           0 RESUME                   0
#           2 LOAD_FAST                0
#           4 LOAD_CONST               1
#           6 BINARY_OP                5 (*)
#          10 RETURN_VALUE

# %%
dobro.__name__
# Out:
# 'dobro'

# %%
dobro2.__name__
# Out:
# '<lambda>'
