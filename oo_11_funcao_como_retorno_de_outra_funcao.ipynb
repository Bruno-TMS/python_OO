# %%
def fabrica_de_multiplicadores():
    def dobro(n):
        return n*2
    
    return dobro

# %%
dobro_externo = fabrica_de_multiplicadores()

# %%
dobro_externo.__name__
# Out:
# 'dobro'

# %%
print(dobro_externo(3))
# Out:
# 6

# %%
dobro_externo_2 = fabrica_de_multiplicadores()

# %%
dobro_externo is dobro_externo_2
# Out:
# False
