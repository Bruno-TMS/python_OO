# %%
def dobro(x):
    return x * 2

# %%
dobro.__name__
# Out:
# 'dobro'

# %%
dobro.__module__
# Out:
# '__main__'

# %%
dobro.__code__
# Out:
# <code object dobro at 0x7dcfa9d36800, file "/tmp/ipykernel_13868/2567538447.py", line 1>

# %%
dobro.__code__.co_code
# Out:
# b'\x97\x00|\x00d\x01z\x05\x00\x00S\x00'

# %%
from dis import dis

dis(dobro.__code__.co_code)
# Out:
#           0 RESUME                   0
#           2 LOAD_FAST                0
#           4 LOAD_CONST               1
#           6 BINARY_OP                5 (*)
#          10 RETURN_VALUE

# %%
dobro.n
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dobro.n
#
# AttributeError: 'function' object has no attribute 'n'

# %%
dobro.n = 42

# %%
dobro.n
# Out:
# 42

# %%
del dobro.n

# %%
dobro.n
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dobro.n
#
# AttributeError: 'function' object has no attribute 'n'

# %%
g = dobro

# %%
g
# Out:
# <function __main__.dobro(x)>

# %%
g.__name__
# Out:
# 'dobro'

# %%
for atributo in dobro.__dir__():
    print(atributo)
# Out:
# __new__
# __repr__
# __call__
# __get__
# __closure__
# __doc__
# __globals__
# __module__
# __builtins__
# __code__
# __defaults__
# __kwdefaults__
# __annotations__
# __dict__
# __name__
# __qualname__
# __type_params__
# __hash__
# __str__
# __getattribute__
# __setattr__
# __delattr__
# __lt__
# __le__
# __eq__
# __ne__
# __gt__
# __ge__
# __init__
# __reduce_ex__
# __reduce__
# __getstate__
# __subclasshook__
# __init_subclass__
# __format__
# __sizeof__
# __dir__
# __class__

# %%
classmethod(dobro)
# Out:
# <classmethod(<function dobro at 0x7dcfa9d42e80>)>
