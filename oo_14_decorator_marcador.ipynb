# %%
_marcadas=[]

# %%
def primeira():
    pass

def segunda():
    pass

# %%
def get_marcadas():
    global _marcadas
    return _marcadas

# %%
def marcar(f):
    global _marcadas
    _marcadas.append(f)
    return f

# %%
primeira = marcar(primeira)
segunda = marcar(segunda)

@marcar
def terceira():
    pass

# %%
for f in get_marcadas():
    print(f.__name__)
# Out:
# primeira
# segunda
# terceira
